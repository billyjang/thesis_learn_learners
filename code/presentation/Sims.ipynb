# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sympy import *
from sklearn.linear_model import LinearRegression
init_printing(use_unicode=True)

# %%
x_1, x_2, x_3, y_1, y_2, y_3, theta_1, theta_2, theta_3 = symbols('x^{(1)} x^{(2)} x^{(3}} y^{(1)} y^{(2)} y^{(3)} \Theta^{(1)} \Theta^{(2)} \Theta^{(3)}')

# %%
def normal(X, y):
    XT = X.T
    XTX = XT*X
    XTX_inv = XTX**-1
    XTy = XT*y
    return XTX_inv * XTy

# %%
def update_normal(X_full, y_full, X_obscured, y_obscured, original_n):
    n,d = X.shape
    #X_list, y_list = X_full.tolist(), y_full.tolist()
    theta_full = []
    lefts = []
    original_X, original_y = X_full[:original_n,:], y_full[:original_n,:]
    original_X_obs, original_y_obs = X_obscured[:original_n,:], y_obscured[:original_n,:]
    
    lm = LinearRegression(fit_intercept=False)
    
    lm.fit(original_X, original_y)
    theta_full.append(lm.coef_[0])
    for i in range(original_n+1, n+1):
        try:
            updated_X, updated_y = X_full[:i,:], y_full[:i,:]
            updated_X_obs, updated_y_obs = X_obscured[:i,:], y_obscured[:i,:]

            lm.fit(updated_X, updated_y)
            theta_full.append(lm.coef_[0])

            left = normal(updated_X_obs, updated_y_obs)
            lefts.append(left)
        except:
            continue
    sys_eqs = []
    diff = len(theta_full) - len(lefts)
    print(diff)
    for i in range(len(lefts)):
        for j in range(d):
            eq = lefts[i][j] - theta_full[i+diff][j]
            sys_eqs.append(eq)
    return theta_full, lefts, sys_eqs
    #return theta_full, lefts
    #return solvers.solve(sys_eqs)

# %%
X = Matrix([[3,4],[1,2],[0,3]])
y = Matrix([5,3,4])
X_obs = Matrix([[x_1,x_2],[1,2],[0,3]])
y_obs = Matrix([y_1,3,4])

# %%
a = update_normal(X,y,X_obs,y_obs,1)
# Out:
# 1

# %%
a[0]
# Out:
# [array([0.6, 0.8]), array([-1.,  2.]), array([-0.10638298,  1.36170213])]

# %%
a[1]
# Out:
# ⎡⎡
# ⎢⎢       (x__{(1)}⋅x__{(2)} + 2)⋅(x__{(2)}⋅y__{(1)} + 6)         (x__{(1)}⋅y__
# ⎢⎢- ────────────────────────────────────────────────────────── + ─────────────
# ⎢⎢  ⎛        2    ⎞ ⎛        2    ⎞                          2
# ⎢⎢  ⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 4⎠ - (x__{(1)}⋅x__{(2)} + 2)
# ⎢⎢
# ⎢⎢                                                ⎛        2    ⎞
# ⎢⎢                                                ⎝x__{(1)}  + 1⎠⋅(x__{(2)}⋅y_
# ⎢⎢                                       ─────────────────────────────────────
# ⎢⎢                                       ⎛        2    ⎞ ⎛        2    ⎞
# ⎣⎣                                       ⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 4⎠ - (x_
#
#            ⎛⎛        2    ⎞ ⎛        2    ⎞
# {(1)} + 3)⋅⎝⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 4⎠ - (-x__{(1)}⋅x__{(2)} - 2)⋅(x__{(1
# ──────────────────────────────────────────────────────────────────────────────
#                  ⎛        2    ⎞ ⎛⎛        2    ⎞ ⎛        2    ⎞
#                  ⎝x__{(1)}  + 1⎠⋅⎝⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 4⎠ - (x__{(1)}⋅
#
#
# _{(1)} + 6)                  (-x__{(1)}⋅x__{(2)} - 2)⋅(x__{(1)}⋅y__{(1)} + 3)
# ───────────────────── + ──────────────────────────────────────────────────────
#                     2   ⎛        2    ⎞ ⎛        2    ⎞
# _{(1)}⋅x__{(2)} + 2)    ⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 4⎠ - (x__{(1)}⋅x__{(2)} +
#
#                                           2⎞⎤  ⎡
# )}⋅x__{(2)} + 2) - (x__{(1)}⋅x__{(2)} + 2) ⎠⎥  ⎢        (x__{(1)}⋅x__{(2)} + 2
# ────────────────────────────────────────────⎥  ⎢- ────────────────────────────
#              2⎞                             ⎥  ⎢  ⎛        2    ⎞ ⎛        2
# x__{(2)} + 2) ⎠                             ⎥  ⎢  ⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  +
#                                             ⎥, ⎢
#                                             ⎥  ⎢
#                                             ⎥  ⎢
# ────                                        ⎥  ⎢
#    2                                        ⎥  ⎢
#  2)                                         ⎦  ⎣
#
#                                                           ⎛⎛        2    ⎞ ⎛
# )⋅(x__{(2)}⋅y__{(1)} + 18)        (x__{(1)}⋅y__{(1)} + 3)⋅⎝⎝x__{(1)}  + 1⎠⋅⎝x_
# ─────────────────────────────── + ────────────────────────────────────────────
#    ⎞                          2                                ⎛        2    ⎞
#  13⎠ - (x__{(1)}⋅x__{(2)} + 2)                                 ⎝x__{(1)}  + 1⎠
#
#                    ⎛        2    ⎞
#                    ⎝x__{(1)}  + 1⎠⋅(x__{(2)}⋅y__{(1)} + 18)                  (
#          ─────────────────────────────────────────────────────────── + ───────
#          ⎛        2    ⎞ ⎛        2     ⎞                          2   ⎛
#          ⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 13⎠ - (x__{(1)}⋅x__{(2)} + 2)    ⎝x__{(1
#
#       2     ⎞
# _{(2)}  + 13⎠ - (-x__{(1)}⋅x__{(2)} - 2)⋅(x__{(1)}⋅x__{(2)} + 2) - (x__{(1)}⋅x
# ──────────────────────────────────────────────────────────────────────────────
#  ⎛⎛        2    ⎞ ⎛        2     ⎞                          2⎞
# ⋅⎝⎝x__{(1)}  + 1⎠⋅⎝x__{(2)}  + 13⎠ - (x__{(1)}⋅x__{(2)} + 2) ⎠
#
#
# -x__{(1)}⋅x__{(2)} - 2)⋅(x__{(1)}⋅y__{(1)} + 3)
# ────────────────────────────────────────────────────
#   2    ⎞ ⎛        2     ⎞                          2
# )}  + 1⎠⋅⎝x__{(2)}  + 13⎠ - (x__{(1)}⋅x__{(2)} + 2)
#
#             2⎞⎤⎤
# __{(2)} + 2) ⎠⎥⎥
# ──────────────⎥⎥
#               ⎥⎥
#               ⎥⎥
#               ⎥⎥
#               ⎥⎥
#               ⎥⎥
#               ⎥⎥
#               ⎥⎥
#               ⎦⎦

# %%
solve(a[2], quick=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
# -> 1308         rf = evalf_table[x.func]
#    1309         r = rf(x, prec, options)
#
# KeyError: <class 'sympy.polys.rootoftools.ComplexRootOf'>
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9760153afcca> in <module>
# ----> 1 solve(a[2], quick=True)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1171         solution = _solve(f[0], *symbols, **flags)
#    1172     else:
# -> 1173         solution = _solve_system(f, symbols, **flags)
#    1174
#    1175     #
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1916                 for s in ok_syms:
#    1917                     try:
# -> 1918                         soln = _solve(eq2, s, **flags)
#    1919                     except NotImplementedError:
#    1920                         continue
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1757     if check:
#    1758         # keep only results if the check is not False
# -> 1759         result = [r for r in result if
#    1760                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1761     return result
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1758         # keep only results if the check is not False
#    1759         result = [r for r in result if
# -> 1760                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1761     return result
#    1762
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     356             if val in (S.true, S.false):
#     357                 return bool(val)
# --> 358             return bool(abs(val.n(18).n(12, chop=True)) < 1e-9)
#     359         was = val
#     360
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1440             options['quad'] = quad
#    1441         try:
# -> 1442             result = evalf(self, prec + 4, options)
#    1443         except NotImplementedError:
#    1444             # Fall back to the ordinary evalf
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_add(v, prec, options)
#     519         options['maxprec'] = min(oldmaxprec, 2*prec)
#     520
# --> 521         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     522         re, re_acc = add_terms(
#     523             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in <listcomp>(.0)
#     519         options['maxprec'] = min(oldmaxprec, 2*prec)
#     520
# --> 521         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     522         re, re_acc = add_terms(
#     523             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_mul(v, prec, options)
#     559     from sympy.core.numbers import Float
#     560     for arg in args:
# --> 561         arg = evalf(arg, prec, options)
#     562         if arg[0] is None:
#     563             continue
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_pow(v, prec, options)
#     676         # base must be evaluated with increased precision if p is large
#     677         prec += int(math.log(abs(p), 2))
# --> 678         re, im, re_acc, im_acc = evalf(base, prec + 5, options)
#     679         # Real to integer power
#     680         if re and not im:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_add(v, prec, options)
#     519         options['maxprec'] = min(oldmaxprec, 2*prec)
#     520
# --> 521         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     522         re, re_acc = add_terms(
#     523             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in <listcomp>(.0)
#     519         options['maxprec'] = min(oldmaxprec, 2*prec)
#     520
# --> 521         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     522         re, re_acc = add_terms(
#     523             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_mul(v, prec, options)
#     559     from sympy.core.numbers import Float
#     560     for arg in args:
# --> 561         arg = evalf(arg, prec, options)
#     562         if arg[0] is None:
#     563             continue
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_pow(v, prec, options)
#     702     # Pure square root
#     703     if exp is S.Half:
# --> 704         xre, xim, _, _ = evalf(base, prec + 5, options)
#     705         # General complex square root
#     706         if xim:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_add(v, prec, options)
#     519         options['maxprec'] = min(oldmaxprec, 2*prec)
#     520
# --> 521         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     522         re, re_acc = add_terms(
#     523             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in <listcomp>(.0)
#     519         options['maxprec'] = min(oldmaxprec, 2*prec)
#     520
# --> 521         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     522         re, re_acc = add_terms(
#     523             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_mul(v, prec, options)
#     559     from sympy.core.numbers import Float
#     560     for arg in args:
# --> 561         arg = evalf(arg, prec, options)
#     562         if arg[0] is None:
#     563             continue
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1307     try:
#    1308         rf = evalf_table[x.func]
# -> 1309         r = rf(x, prec, options)
#    1310     except KeyError:
#    1311         # Fall back to ordinary evalf if possible
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf_pow(v, prec, options)
#     676         # base must be evaluated with increased precision if p is large
#     677         prec += int(math.log(abs(p), 2))
# --> 678         re, im, re_acc, im_acc = evalf(base, prec + 5, options)
#     679         # Real to integer power
#     680         if re and not im:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1312         if 'subs' in options:
#    1313             x = x.subs(evalf_subs(prec, options['subs']))
# -> 1314         xe = x._eval_evalf(prec)
#    1315         if xe is None:
#    1316             raise NotImplementedError
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rootoftools.py in _eval_evalf(self, prec, **kwargs)
#     871         """Evaluate this complex root to the given precision."""
#     872         # all kwargs are ignored
# --> 873         return self.eval_rational(n=prec_to_dps(prec))._evalf(prec)
#     874
#     875     def eval_rational(self, dx=None, dy=None, n=15):
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rootoftools.py in eval_rational(self, dx, dy, n)
#     942                     dx = abs(interval.center[0]*rtol)
#     943                     dy = abs(interval.center[1]*rtol)
# --> 944                 interval = interval.refine_size(dx, dy)
#     945                 c = interval.center
#     946                 real, imag = map(Rational, c)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rootisolation.py in refine_size(self, dx, dy)
#    2059         expr = self
#    2060         while not (expr.dx < dx and expr.dy < dy):
# -> 2061             expr = expr._inner_refine()
#    2062
#    2063         return expr
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rootisolation.py in _inner_refine(self)
#    2029
#    2030         if s - u > t - v:
# -> 2031             D_L, D_R = _vertical_bisection(1, (u, v), (s, t), I, Q, F1, F2, f1, f2, dom)
#    2032
#    2033             if D_L[0] == 1:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rootisolation.py in _vertical_bisection(N, a, b, I, Q, F1, F2, f1, f2, F)
#    1290     f2V = dmp_eval_in(f2, x, 0, 1, F)
#    1291
# -> 1292     I_V = dup_isolate_real_roots_list([f1V, f2V], F, inf=v, sup=t, fast=True, strict=True, basis=True)
#    1293
#    1294     I_L1_L, I_L1_R = [], []
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rootisolation.py in dup_isolate_real_roots_list(polys, K, eps, inf, sup, strict, basis, fast)
#     591             zero_indices[i] = j
#     592
# --> 593         for f, k in dup_factor_list(p, K)[1]:
#     594             f = tuple(f)
#     595
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/factortools.py in dup_factor_list(f, K0)
#    1204
#    1205         if K.is_ZZ:
# -> 1206             coeff, factors = dup_zz_factor(f, K)
#    1207         elif K.is_Poly:
#    1208             f, u = dmp_inject(f, 0, K)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/factortools.py in dup_zz_factor(f, K)
#     620
#     621     if H is None:
# --> 622         H = dup_zz_zassenhaus(g, K)
#     623
#     624     factors = dup_trial_division(f, H, K)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/factortools.py in dup_zz_zassenhaus(f, K)
#     297     modular = [gf_to_int_poly(ff, p) for ff in fsqf]
#     298
# --> 299     g = dup_zz_hensel_lift(p, f, modular, l, K)
#     300
#     301     sorted_T = range(len(g))
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/factortools.py in dup_zz_hensel_lift(p, f, f_list, l, K)
#     247
#     248     for _ in range(1, d + 1):
# --> 249         (g, h, s, t), m = dup_zz_hensel_step(m, f, g, h, s, t, K), m**2
#     250
#     251     return dup_zz_hensel_lift(p, g, f_list[:k], l, K) \
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/factortools.py in dup_zz_hensel_step(m, f, g, h, s, t, K)
#     171     e = dup_trunc(e, M, K)
#     172
# --> 173     q, r = dup_div(dup_mul(s, e, K), h, K)
#     174
#     175     q = dup_trunc(q, M, K)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/densearith.py in dup_div(f, g, K)
#    1530         return dup_ff_div(f, g, K)
#    1531     else:
# -> 1532         return dup_rr_div(f, g, K)
#    1533
#    1534
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/densearith.py in dup_rr_div(f, g, K)
#    1345         q = dup_add_term(q, c, j, K)
#    1346         h = dup_mul_term(g, c, j, K)
# -> 1347         r = dup_sub(r, h, K)
#    1348
#    1349         _dr, dr = dr, dup_degree(r)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/densearith.py in dup_sub(f, g, K)
#     590
#     591
# --> 592 def dup_sub(f, g, K):
#     593     """
#     594     Subtract dense polynomials in ``K[x]``.
#
# KeyboardInterrupt:

# %%
X = Matrix([[3,4,5],[1,2,3],[9,3,1],[8,2,4]])
y = Matrix([6,4,-4,7])
X_obs = Matrix([[x_1,x_2,x_3],[1,2,3],[9,3,1],[8,2,4]])
y_obs = Matrix([y_1,4,-4,7])

# %%
a = update_normal(X,y,X_obs,y_obs,1)
# Out:
# 2

# %%
a[0]
# Out:
# [array([0.36, 0.48, 0.6 ]),
#  array([-0.66666667,  0.33333333,  1.33333333]),
#  array([-0.75,  0.5 ,  1.25]),
#  array([-0.04339623, -2.15471698,  2.90754717])]

# %%
solve(a[2], quick=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-9760153afcca> in <module>
# ----> 1 solve(a[2], quick=True)
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1171         solution = _solve(f[0], *symbols, **flags)
#    1172     else:
# -> 1173         solution = _solve_system(f, symbols, **flags)
#    1174
#    1175     #
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1850             else:
#    1851                 try:
# -> 1852                     result = solve_poly_system(polys, *symbols)
#    1853                     if result:
#    1854                         solved_syms = symbols
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/polysys.py in solve_poly_system(seq, *gens, **args)
#      45                 pass
#      46
# ---> 47     return solve_generic(polys, opt)
#      48
#      49
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/polysys.py in solve_generic(polys, opt)
#     235
#     236     try:
# --> 237         result = _solve_reduced_system(polys, opt.gens, entry=True)
#     238     except CoercionFailed:
#     239         raise NotImplementedError
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/solvers/polysys.py in _solve_reduced_system(system, gens, entry)
#     183             return [ (zero,) for zero in zeros ]
#     184
# --> 185         basis = groebner(system, gens, polys=True)
#     186
#     187         if len(basis) == 1 and basis[0].is_ground:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/polytools.py in groebner(F, *gens, **args)
#    6768
#    6769     """
# -> 6770     return GroebnerBasis(F, *gens, **args)
#    6771
#    6772
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/polytools.py in __new__(cls, F, *gens, **args)
#    6807         polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
#    6808
# -> 6809         G = _groebner(polys, ring, method=opt.method)
#    6810         G = [Poly._from_dict(g, opt) for g in G]
#    6811
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/groebnertools.py in groebner(seq, ring, method)
#      43             seq = [ s.set_ring(ring) for s in seq ]
#      44
# ---> 45     G = _groebner(seq, ring)
#      46
#      47     if orig is not None:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/groebnertools.py in _buchberger(f, ring)
#     238         # ordering divisors is on average more efficient [Cox] page 111
#     239         G1 = sorted(G, key=lambda g: order(f[g].LM))
# --> 240         ht = normal(h, G1)
#     241
#     242         if ht:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/groebnertools.py in normal(g, J)
#     109             return None
#     110         else:
# --> 111             h = h.monic()
#     112
#     113             if not h in I:
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rings.py in monic(f)
#    1959             return f
#    1960         else:
# -> 1961             return f.quo_ground(f.LC)
#    1962
#    1963     def mul_ground(f, x):
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rings.py in quo_ground(f, x)
#    1995         if domain.is_Field:
#    1996             quo = domain.quo
# -> 1997             terms = [ (monom, quo(coeff, x)) for monom, coeff in f.iterterms() ]
#    1998         else:
#    1999             terms = [ (monom, coeff // x) for monom, coeff in f.iterterms() if not (coeff % x) ]
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/rings.py in <listcomp>(.0)
#    1995         if domain.is_Field:
#    1996             quo = domain.quo
# -> 1997             terms = [ (monom, quo(coeff, x)) for monom, coeff in f.iterterms() ]
#    1998         else:
#    1999             terms = [ (monom, coeff // x) for monom, coeff in f.iterterms() if not (coeff % x) ]
#
# /anaconda3/envs/T02/lib/python3.7/site-packages/sympy/polys/domains/gmpyrationalfield.py in quo(self, a, b)
#      70     def quo(self, a, b):
#      71         """Quotient of `a` and `b`, implies `__div__`. """
# ---> 72         return GMPYRational(a) / GMPYRational(b)
#      73
#      74     def rem(self, a, b):
#
# KeyboardInterrupt:
